# %%
import configparser
from datetime import datetime, timedelta
import os
import sys
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format, dayofweek
from pyspark.sql.functions import monotonically_increasing_id
from pyspark.sql.types import DateType,StringType
from pyspark.sql import functions as F
from pyspark.sql.functions import avg
import pandas as pd

# %%
import pandas as pd

# %%
tools_df = pd.read_json('D:/hieulon.json')
tools_df.head()
# Out:
#         name                    category  countCompanies        Stage  \
# 0     &facts  Business Intelligence (BI)               0  Early Stage
# 1         5X          Managed Data Stack               0  Early Stage
# 2  Acceldata     Data Quality Monitoring               1  Early Stage
# 3       Acho  Business Intelligence (BI)               0  Early Stage
# 4      Acryl             Data Cataloging               0  Early Stage
#
#                  Target Segment Deployment Business Model  \
# 0  SMBs / Mid-size / Enterprise       SaaS     Commercial
# 1         Mid Size / Enterprise       SaaS     Commercial
# 2                      Mid size       SaaS     Commercial
# 3         Mid size / Enterprise       SaaS     Commercial
# 4                      Mid size       SaaS     Commercial
#
#                       Pricing                                  Location
# 0                  Free trial                               Birmingham
# 1               Contact Sales                                 Singapore
# 2               Contact Sales                            California, US
# 3  Contact Sales / Free trial                                Boston, US
# 4               Not Available  Mountain View, California, United States

# %%
results = tools_df[tools_df['category'] == 'Business Intelligence (BI)']

# %%
results.head()
# Out:
#                   name                    category  countCompanies  \
# 0               &facts  Business Intelligence (BI)               0
# 3                 Acho  Business Intelligence (BI)               0
# 19  Amazon Quick Sight  Business Intelligence (BI)               1
# 26              Anteam  Business Intelligence (BI)               0
# 40             Astrato  Business Intelligence (BI)               0
#
#           Stage                Target Segment Deployment Business Model  \
# 0   Early Stage  SMBs / Mid-size / Enterprise       SaaS     Commercial
# 3   Early Stage         Mid size / Enterprise       SaaS     Commercial
# 19   Late Stage         Mid size / Enterprise       SaaS     Commercial
# 26  Early Stage               SMBs / Mid Size       SaaS     Commercial
# 40  Early Stage  SMBs / Mid-Size / Enterprise       SaaS     Commercial
#
#                        Pricing     Location
# 0                   Free trial  Birmingham
# 3   Contact Sales / Free trial   Boston, US
# 19                    Freemium           US
# 26                  Free Trial        India
# 40    Freemium / Contact Sales       London

# %%
results = results[results['Business Model']=='Open Source']
results.head(11)
# Out:
#           name                    category  countCompanies        Stage  \
# 100   Cube.dev  Business Intelligence (BI)               0    Mid Stage
# 238  Lightdash  Business Intelligence (BI)               2  Early Stage
# 251   Metabase  Business Intelligence (BI)              11    Mid Stage
# 337     Redash  Business Intelligence (BI)               4    Mid Stage
# 401   Superset  Business Intelligence (BI)               4  Early Stage
# 422    Tellery  Business Intelligence (BI)               0  Early Stage
#
#             Target Segment      Deployment Business Model     Pricing  \
# 100               Mid size     Open source    Open Source  Free trial
# 238        Mid size / SMBs     Open source    Open Source    Freemium
# 251  Mid size / Enterprise            SaaS    Open Source    Freemium
# 337  Mid size / Enterprise  SaaS / On Prem    Open Source  Free trial
# 401               Mid size            SaaS    Open Source    Freemium
# 422               Mid size     Open source    Open Source  Free trial
#
#               Location
# 100      San Francisco
# 238                 UK
# 251  San Francisco, US
# 337                 US
# 401                 US
# 422                 US

# %%
category_df = tools_df['category'].to_frame()
category_df = category_df.drop_duplicates(keep='first',inplace=False).reset_index(drop=True)
category_df.head(50)
# Out:
#                               category
# 0           Business Intelligence (BI)
# 1                   Managed Data Stack
# 2              Data Quality Monitoring
# 3                      Data Cataloging
# 4                 Spreadsheet based BI
# 5          Customer Data Platform(CDP)
# 6                  Augmented Analytics
# 7        Data Workspace/ Collaboration
# 8                       Synthetic Data
# 9                            ETL Tools
# 10              Workflow Orchestration
# 11                      Data Discovery
# 12         Data Privacy and Governance
# 13                       Feature Store
# 14  Business Reliability/Observability
# 15                      Data Streaming
# 16                          Data Lakes
# 17   Data Modelling and Transformation
# 18              Operational Analytics
# 19                     Data Warehouses
# 20                             PLG CRM
# 21                   Reverse ETL Tools
# 22                  No code automation
# 23                           Data Mesh
# 24                           Data Apps
# 25                 Change Data Capture
# 26                   Product Analytics
# 27                       Metrics Store
# 28                        Data Logging
