# %%
import configparser
from datetime import datetime, timedelta
import os
import sys
import pandas as pd

# %%
import pandas as pd

# %%
tools_df = pd.read_json('D:/hieulon.json')
tools_df = tools_df[tools_df['category']=='Data Gorvernance']
tools_df = tools_df[tools_df['category']!='Business Intelligence (BI)']
tools_df = tools_df[tools_df['category']!='Workflow Orchestration']
tools_df = tools_df.sort_values(by=['category'])
tools_df.head(50)
# Out:
#                     name                           category  countCompanies  \
# 219                Kausa                Augmented Analytics               0
# 127             debezium                Change Data Capture               1
# 28          Apache Atlas                    Data Cataloging               1
# 245              Marquez                    Data Cataloging               0
# 22              Amundsen                     Data Discovery               2
# 290  Open Data Discovery                     Data Discovery               0
# 234               Lakefs                         Data Lakes               0
# 31           Apache Hudi                         Data Lakes               2
# 230                 Kylo                         Data Lakes               0
# 130             Delta.io                         Data Lakes               3
# 458              whylabs                       Data Logging               0
# 378             Snowplow                       Data Logging               6
# 35          Apache Spark  Data Modelling and Transformation               5
# 126                  dbt  Data Modelling and Transformation             100
# 336              re_data            Data Quality Monitoring               0
# 181              Griffin            Data Quality Monitoring               0
# 177   Great Expectations            Data Quality Monitoring               2
# 140      Elementary Data            Data Quality Monitoring               0
# 30        Apache Griffin            Data Quality Monitoring               0
# 246          Materialize                     Data Streaming               1
# 184            hazelcast                     Data Streaming               0
# 36          Apache Storm                     Data Streaming               5
# 227               KsqlDB                     Data Streaming               0
# 32          Apache Kafka                     Data Streaming              18
# 29          Apache Flink                     Data Streaming               4
# 349                Samza                     Data Streaming               0
# 192                 Hive                    Data Warehouses               1
# 333            Querybook      Data Workspace/ Collaboration               0
# 369               Singer                          ETL Tools               0
# 281        Nunchi Studio                          ETL Tools               0
# 255            Metorikku                          ETL Tools               1
# 10               Airbyte                          ETL Tools               3
# 249              Meltano                          ETL Tools               3
# 195            hopsworks                      Feature Store               0
# 265             Molecula                      Feature Store               3
# 154                Feast                      Feature Store               0
# 202              iguazio                      Feature Store               3
# 257              MetriQL                      Metrics Store               0
# 272                  N8N                 No code automation               0
# 223              Kimball                            PLG CRM               0
# 316             Post Hog                  Product Analytics               1
# 282             Objectiv                  Product Analytics               0
# 78               Castled                  Reverse ETL Tools               0
# 441              Twinify                     Synthetic Data               0
# 178     Gretel Synthetic                     Synthetic Data               0
# 374          Smart Noise                     Synthetic Data               0
# 405               Synner                     Synthetic Data               0
# 407                Synth                     Synthetic Data               0
# 408              Synthea                     Synthetic Data               0
# 210           Instill Ai                     Synthetic Data               0
#
#            Stage                Target Segment             Deployment  \
# 219  Early Stage         Mid size / Enterprise            Open source
# 127   Late Stage                      Mid size            Open source
# 28     Mid Stage                    Enterprise            Open source
# 245    Mid Stage                      Mid size                On Prem
# 22   Early Stage                      Mid size                On Prem
# 290  Early Stage         Mid Size / Enterprise            Open Source
# 234  Early Stage                      Mid size            Open source
# 31   Early Stage         Mid Size / Enterprise            Open Source
# 230    Mid Stage                    Enterprise                   SaaS
# 130    Mid Stage         Enterprise / Mid size         SaaS / On Prem
# 458  Early Stage  Mid size / Enterprise / SMBs            Open source
# 378   Late Stage         Mid size / Enterprise            Open source
# 35    Late Stage         Mid Size / Enterprise                On Prem
# 126  Early Stage         Enterprise / Mid size                   SaaS
# 336  Early Stage  Enterprise / Mid size / SMBs            Open source
# 181    Mid Stage         Enterprise / Mid size                On Prem
# 177  Early Stage                      Mid size                On Prem
# 140  Early Stage                      Mid Size            Open Source
# 30   Early Stage                      Mid size            Open source
# 246   Late Stage         Enterprise / Mid size                On Prem
# 184   Late Stage         Enterprise / Mid size         SaaS / On Prem
# 36    Late Stage         Enterprise / Mid size                On Prem
# 227  Early Stage                      Mid size            Open source
# 32    Late Stage         Enterprise / Mid size                On Prem
# 29    Late Stage         Enterprise / Mid size                On Prem
# 349  Early Stage         Mid size / Enterprise            Open source
# 192   Late Stage         Mid Size / Enterprise                On Prem
# 333    Mid Stage         Mid size / Enterprise            Open source
# 369  Early Stage         Mid Size / Enterprise            Open Source
# 281  Early Stage                      Mid Size            Open Source
# 255  Early Stage                      Mid Size            Open Source
# 10   Early Stage         Enterprise / Mid size                   SaaS
# 249  Early Stage         Mid size / Enterprise            Open source
# 195  Early Stage         Mid size / Enterprise                   SaaS
# 265    Mid Stage         Mid size / Enterprise                   SaaS
# 154  Early Stage                    Enterprise                   SaaS
# 202    Mid Stage         Mid size / Enterprise                   SaaS
# 257  Early Stage                      Mid size     SaaS / Open source
# 272  Early Stage                      Mid size         On Prem / SaaS
# 223  Early Stage                      Mid size                On Prem
# 316  Early Stage         Enterprise / Mid size            Open source
# 282    Mid Stage                      Mid Size            Open Source
# 78   Early Stage               SMBs / Mid size                   SaaS
# 441  Early Stage                      Mid size  Open source / On Prem
# 178  Early Stage                      Mid size  Open source / On Prem
# 374  Early Stage                      Mid size  On Prem / Open source
# 405    Mid Stage                      Mid size  Open source / On Prem
# 407  Early Stage                      Mid size  Open source / On Prem
# 408  Early Stage                      Mid size            Open source
# 210  Early Stage                      Mid size            Open source
#
#     Business Model                     Pricing                        Location
# 219    Open Source               Contact Sales                 Berlin, Germany
# 127    Open Source                    Freemium                              US
# 28     Open Source                    Freemium                              US
# 245    Open Source                    Freemium                              US
# 22     Open Source                  Free trial                              US
# 290    Open Source                    Freemium                              US
# 234    Open Source                    Freemium                Tel Aviv, Israel
# 31     Open Source                    Freemium                  California, US
# 230    Open Source                    Freemium                  California, US
# 130    Open Source                  Free trial                              US
# 458    Open Source                    Freemium                     Seattle, US
# 378    Open Source                    Freemium                 London, England
# 35     Open Source                    Freemium                              US
# 126    Open Source  Free trial / Contact Sales                              US
# 336    Open Source                    Freemium                  Warsaw, Poland
# 181    Open Source                    Freemium                              US
# 177    Open Source                    Freemium                  California, US
# 140    Open Source                    Freemium                              US
# 30     Open Source               Not Available              Houston, Texas, US
# 246    Open Source                    Freemium                    New York, US
# 184    Open Source                    Freemium                  California, US
# 36     Open Source                    Freemium                              US
# 227    Open Source                    Freemium                  California, US
# 32     Open Source                    Freemium                              US
# 29     Open Source                    Freemium                              US
# 349    Open Source               Not Available  Wakefield, Massachusetts, U.S.
# 192    Open Source                    Freemium                              US
# 333    Open Source                    Freemium                              US
# 369    Open Source                    Freemium                              US
# 281    Open Source               Contact Sales                   Paris, France
# 255    Open Source                    Freemium                    New York, US
# 10     Open Source               Contact Sales               San Francisco, US
# 249    Open Source                    Freemium                              US
# 195    Open Source    Freemium / Contact Sales                          Sweden
# 265    Open Source               Contact Sales                       Texas, US
# 154    Open Source                  Free trial                  California, US
# 202    Open Source  Free trial / Contact Sales                Herzliya, Israel
# 257    Open Source                    Freemium                              US
# 272    Open Source                    Freemium                          Berlin
# 223    Open Source               Contact Sales                Philadelphia, US
# 316    Open Source    Freemium / Contact Sales       San Francisco, California
# 282    Open Source                        Free            Utrecht, Netherlands
# 78     Open Source                  Free trial                           India
# 441    Open Source                    Freemium                              US
# 178    Open Source                    Freemium       San Diego, California, US
# 374    Open Source                    Freemium                              US
# 405    Open Source                    Freemium                              US
# 407    Open Source                    Freemium                              US
# 408    Open Source                    Freemium                              US
# 210    Open Source                    Freemium                              US

# %%
results = tools_df[tools_df['category'] == 'Data Cataloging']
results = results[results['Business Model']=='Open Source']
results.head(20)
# Out:
#             name         category  countCompanies      Stage Target Segment  \
# 28  Apache Atlas  Data Cataloging               1  Mid Stage     Enterprise
#
#      Deployment Business Model   Pricing Location
# 28  Open source    Open Source  Freemium       US

# %%
results.head()
# Out:
#             name         category  countCompanies      Stage Target Segment  \
# 28  Apache Atlas  Data Cataloging               1  Mid Stage     Enterprise
#
#      Deployment Business Model   Pricing Location
# 28  Open source    Open Source  Freemium       US

# %%
results = results[results['Business Model']=='Open Source']
results.head(20)
# Out:
#             name         category  countCompanies      Stage Target Segment  \
# 28  Apache Atlas  Data Cataloging               1  Mid Stage     Enterprise
#
#      Deployment Business Model   Pricing Location
# 28  Open source    Open Source  Freemium       US

# %%
category_df = tools_df['category'].to_frame()
category_df = category_df.drop_duplicates(keep='first',inplace=False).reset_index(drop=True)
category_df.head(50)
# Out:
#                              category
# 0                 Change Data Capture
# 1                     Data Cataloging
# 2                      Data Discovery
# 3                          Data Lakes
# 4                        Data Logging
# 5   Data Modelling and Transformation
# 6             Data Quality Monitoring
# 7                      Data Streaming
# 8                     Data Warehouses
# 9                           ETL Tools
# 10                      Feature Store
# 11                  Product Analytics
